# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("train1.csv")
df2 = pd.read_csv("test1.csv")

# %%
df1.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df1.describe().transpose()
# Out:
#                              count          mean           std           min  \
# ID                        100000.0  8.063150e+04  4.330149e+04   5634.000000
# Customer_ID               100000.0  2.598267e+04  1.434054e+04   1006.000000
# Month                     100000.0  4.500000e+00  2.291299e+00      1.000000
# Age                       100000.0  3.331634e+01  1.076481e+01     14.000000
# SSN                       100000.0  5.004617e+08  2.908267e+08  81349.000000
# Annual_Income             100000.0  5.050512e+04  3.829942e+04   7005.930000
# Monthly_Inhand_Salary     100000.0  4.197271e+03  3.186432e+03    303.645417
# Num_Bank_Accounts         100000.0  5.368820e+00  2.593314e+00      0.000000
# Num_Credit_Card           100000.0  5.533570e+00  2.067098e+00      0.000000
# Interest_Rate             100000.0  1.453208e+01  8.741330e+00      1.000000
# Num_of_Loan               100000.0  3.532880e+00  2.446356e+00      0.000000
# ...

# %%
#checking if there are any null values
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1['Credit_Mix'] = df1['Credit_Mix'].map({'Good': 2, 'Standard': 1, 'Bad': 0})

# %%
plt.figure(figsize=(15, 10))

# %%
# Distribution of Credit Score
plt.subplot(2, 2, 1)
sns.histplot(df1['Credit_Score'], kde=True, color='skyblue')
plt.title('Distribution of Credit Score')
# Out:
# Text(0.5, 1.0, 'Distribution of Credit Score')

# %%
# Box plots to visualize the relationship between Credit Score and other features
fig, ax = plt.subplots(5, 3, figsize=(15, 20))
ax = ax.flatten()
features = ["Annual_Income", "Monthly_Inhand_Salary", "Num_Bank_Accounts", "Num_Credit_Card", 
             "Interest_Rate", "Num_of_Loan", "Delay_from_due_date", "Num_of_Delayed_Payment", 
             "Outstanding_Debt", "Credit_History_Age", "Monthly_Balance", "Credit_Mix"]

for i, feature in enumerate(features):
    sns.boxplot(x='Credit_Score', y=feature, data=df1, ax=ax[i], palette='Set2')
    ax[i].set_title(f'Credit Score vs {feature}', fontsize=12)
    ax[i].set_xlabel('Credit Score')
    ax[i].set_ylabel(feature)

fig.tight_layout()
plt.suptitle('Boxplots of Credit Score vs Features', fontsize=16, y=1.02)
# Out:
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_1760\2422602002.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Credit_Score', y=feature, data=df1, ax=ax[i], palette='Set2')
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_1760\2422602002.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Credit_Score', y=feature, data=df1, ax=ax[i], palette='Set2')
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_1760\2422602002.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
df1['Credit_Mix'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X = df1[["Annual_Income", "Monthly_Inhand_Salary", "Num_Bank_Accounts", "Num_Credit_Card", "Interest_Rate", "Num_of_Loan", 
        "Delay_from_due_date", "Num_of_Delayed_Payment", "Credit_Mix", "Outstanding_Debt", "Credit_History_Age", 
        "Monthly_Balance"]].values
y = df1['Credit_Score'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=300, class_weight='balanced')
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300)

# %%
# Making predictions on our model using the test data
predictions = model.predict(X_test)
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.78      0.75      0.77      5866
#         Poor       0.80      0.83      0.81      9633
#     Standard       0.82      0.81      0.82     17501
#
#     accuracy                           0.81     33000
#    macro avg       0.80      0.80      0.80     33000
# weighted avg       0.81      0.81      0.81     33000
#
#
#
# Confusion Matrix [[ 4425    28  1413]
#  [   20  7948  1665]
#  [ 1256  2002 14243]]
#
#
# Accuracy Score 0.8065454545454546

# %%
# Additional test predictions on new data

test_data = df2[["Annual_Income", "Monthly_Inhand_Salary", "Num_Bank_Accounts", "Num_Credit_Card", 
                  "Interest_Rate", "Num_of_Loan", "Delay_from_due_date", "Num_of_Delayed_Payment", 
                  "Credit_Mix", "Outstanding_Debt", "Credit_History_Age", "Monthly_Balance"]].values

# %%
# Making predictions on the new dataset
test_predictions = model.predict(test_data)

# %%
# Displaying predictions for the test data
df2['Predicted_Credit_Score'] = test_predictions

# %%
df2.head()  # Display the first few rows with predictions
# Out:
#      ID  Customer_ID  Month             Name   Age          SSN Occupation  \
# 0  5642         3392      9    Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5643         3392     10    Aaron Maashoh  24.0  821000265.0  Scientist
# 2  5644         3392     11    Aaron Maashoh  24.0  821000265.0  Scientist
# 3  5645         3392     12    Aaron Maashoh  24.0  821000265.0  Scientist
# 4  5654         8625      9  Rick Rothackerj  28.0    4075839.0    Teacher
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...           2
# 1       19114.12            1824.843333                3.0  ...           2
# 2       19114.12            1824.843333                3.0  ...           2
# 3       19114.12            1824.843333                3.0  ...           2
# 4       34847.84            3037.986667                2.0  ...           2
#
# ...
